# %%
# Write a program to add any two numbers
num1 = 20
num2 = 10
answer = num1+num2

# %%
surname = 'Lasisi'
age = 30

# %%
age = '20'
print(age*3)
# Out:
# 202020

# %%
num1 = '5'
num2 = '10'
print(num1+num2)
# Out:
# 510

# %%
nums = [10,5,8,20]

# %%
nums[3]
# Out:
# 20

# %%
len(nums)
# Out:
# 4

# %%
num1 = 20
num2 = 20
print(num1*num2)
# Out:
# 400

# %%
surname = 'Lasisi'
name = 'basit'
age = '10'
print(surname+name+age)
# Out:
# Lasisibasit10
