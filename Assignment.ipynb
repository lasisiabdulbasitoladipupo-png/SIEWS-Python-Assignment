# %%
# which month has the highest average profit magin?

# %%
# Group by Month_Name and calculate average Profit_Margin
avg_margin_month = df_balanced.groupby('Month_Name')['Profit_Margin'].mean().sort_values(ascending=False)

# Display the result
print("Average Profit Margin by Month:")
print(avg_margin_month)

# Quick visualization
avg_margin_month.plot(kind='bar', color='skyblue', title='Avg Profit Margin per Month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Group by Month_Name and calculate average Profit_Margin
# ----> 2 avg_margin_month = df_balanced.groupby('Month_Name')['Profit_Margin'].mean().sort_values(ascending=False)
#       4 # Display the result
#       5 print("Average Profit Margin by Month:")
#
# NameError: name 'df_balanced' is not defined
