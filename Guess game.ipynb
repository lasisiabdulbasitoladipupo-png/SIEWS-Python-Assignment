# %%
# write a programm that ask a user to enter a product one by one
# keep adding items until the user type stop

# %%
products = []

while True:
    product = input('Enter product name: ')
    products.append(product)
    print('product added')
    print(products)
    Q = input('Do you want to continue?yes/no')
    if Q=='yes':
        print('Thankyou for using the app')
        break
# Out:
# Enter product name:  Infinix
# product added
# ['Infinix']
# Do you want to continue?yes/no yes
# Thankyou for using the app

# %%
# write a python program to create a guess game

# %%
# Guess Game
import random
score = 0
live = 5
player = input('Enter your name: ')
print(f'hi, {player}. welcome to playstation!')
while True:
    if live == 0:
        print('Game Over!')
        break
    systemGuess = random.randint(1, 6)
    myGuess = int(input ('Guess a number: '))
    if systemGuess == myGuess:
        print(f'Great! System guessed {systemGuess}')
        score = score+5
        print(f'Your new score is {score}')
    else:
        print(f'Sorry! System guessed {systemGuess}')
        if score>0:
            score = score - 5
        live = live -1
        print(f'Your new score is {score} and live left is {live}')
# Out:
# Enter your name:  Oladipupo
# hi, Oladipupo. welcome to playstation!
# Guess a number:  2
# Sorry! System guessed 5
# Your new score is -5 and live left is 4
# Guess a number:  1
# Sorry! System guessed 6
# Your new score is -10 and live left is 3
# Guess a number:  3
# Great! System guessed 3
# Your new score is -5
# Guess a number:  5
# Great! System guessed 5
# Your new score is 0
# Guess a number:  4
# Great! System guessed 4
# Your new score is 5
# Guess a number:  1
# Sorry! System guessed 5
# Your new score is 0 and live left is 2
# Guess a number:  4
# Sorry! System guessed 3
# Your new score is -5 and live left is 1
# Guess a number:  1
# Sorry! System guessed 3
# Your new score is -10 and live left is 0
# Game Over!

# %%
# ask a use to enter any number, use a for loop to print any number from 1 to 12

# %% [markdown]
# num = int(input('Enter a number for multiplication table'))
# for n in range(1, 13):
#     print(f'{num} * {n} = {num*n}')

# %%
# write a python program to print all even numbers between 1 to 50
