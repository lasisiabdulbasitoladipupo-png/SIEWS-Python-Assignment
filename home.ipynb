# %%
profile = {
    'FirstName': 'Abdul Basit',
    'LastName': 'Lasisi',
    'Age': 18,
    'Address':{
    'country': 'USA',
    'State': 'Arizona',
    'LGA': 'WestBridge',
    },
    'Vehicle perticulaars':{
    'Driving liesence': 'ARN 001 JK',
    'Car': 'Mecedes Benz  GLE600 AMG',
    'MODEL': '2026'
    'Plate Number' 'PRESIDENCY001',
    'Colour': 'Sliver',
    },

    'MatricNum': 'GLE-750-SPORT',
}

# %%
profile['Address']['country']
# Out:
# 'USA'

# %%
profile['FirstName']
# Out:
# 'Abdul Basit'

# %%
print('MatricNum')
# Out:
# MatricNum

# %%
profile
# Out:
# {'FirstName': 'Abdul Basit',
#  'LastName': 'Lasisi',
#  'Age': 18,
#  'Address': {'country': 'USA', 'State': 'Arizona', 'LGA': 'WestBridge'},
#  'Vehicle perticulaars': {'Driving liesence': 'ARN 001 JK',
#   'Car': 'Mecedes Benz  GLE600 AMG',
#   'MODEL': '2026Plate NumberPRESIDENCY001',
#   'Colour': 'Sliver'},
#  'MatricNum': 'GLE-750-SPORT'}

# %%
# write a program to create a password
hints = []
num = int(input('How many passwords do you want to create?'))
for n in range(num):
    print(f'Enter hint {n+1}')
    hintName = input('Enter hint name')
    password = input('Enter password characters: ')
    password = {
        'name': passwordscharacter,
        'password': password
    }
    books.append(book)
print('All passwords are been saved')
# Out:
# How many passwords do you want to create? 2
# Enter hint 1
# Enter hint name look@me
# Enter password characters:  Knock123
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       6     hintName = input('Enter hint name')
#       7     password = input('Enter password characters: ')
#       8     password = {
# ----> 9         'name': passwordscharacter,
#      10         'password': password
#      11     }
#      12     books.append(book)
#      13 print('All passwords are been saved')
#
# NameError: name 'passwordscharacter' is not defined
