# %%
# !pip install pands

# %%
import pandas as pd

# %%
prit(4+4)

# %%
#logical and comparison operators
#working with loopd
#using if..elif..else statement
#accessing excel file for data analysis

# %%
#AND,NAND,NOR,OR
==, !=,

# %%
a = 40
b = 30
a > b ? AND a < b ?
a <= b OR a>=b
F or F > F OR T or F > T
F OR T = T

# %%
a<b or a==b
f   or f = f

a>b or a==b
t   or f = t

f or t = t
____________________
b = 25
c = 30
b==b OR ((b>=c) AND ((C==B)) ?
  T    OR     F    AND     F
       T     AND    F
              F
# Out:
#   Cell In[1], line 2
#     f   or f = f
#     ^
# SyntaxError: cannot assign to expression

# %%
nums = [ 5,6,8,3,2 ]
for n in nums:
    print(n)
# Out:
# 5
# 6
# 8
# 3
# 2
